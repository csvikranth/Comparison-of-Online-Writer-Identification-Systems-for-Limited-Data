# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import xml.etree.ElementTree as ET  
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from statistics import mean
import math
import os
import pandas as pd
import scipy.stats as stats
import csv

# %%
def exctract_features(path):
  features={}

  tree = ET.parse(path)
  root = tree.getroot()
  #Print Description
  #for x in root[0]:
    #print(x.text)
  #Extraction of coordinates
  a=[]
  b=[]
  all_x=[]
  all_y=[]
  x_coordinates = []
  y_coordinates = []
  for i in range(1,len(root)):
    for x in root[i]:
      if (x.text=='\n\t\t\t'):
        continue
      else:
        l = list(map(str,x.text.split(',')))
        l = [x.strip() for x in l]
        for x in l:
          xy = list(map(int,x.split(' ')))
          x_coordinates.append(xy[0])
          y_coordinates.append(xy[1])
        a.append(x_coordinates)
        b.append(y_coordinates)
        x_coordinates = []
        y_coordinates = []  
  for i in range(len(a)):
    for j in range(len(a[i])):
      all_x.append(a[i][j])
      all_y.append(b[i][j])
  
  #Time Stamp
  time_stamp = np.arange(0,len(all_x)*0.02,0.02)
  
  #Relative_x_y
  relative_x=[0]
  relative_y=[0]
  for i in range(1,len(all_x)):
    relative_x.append(all_x[i]-mean(all_x[:i]))
    relative_y.append(all_y[i]-mean(all_y[:i]))
  features['relative_x']=relative_x
  features['relative_y']=relative_y

  #Speed
  tracewise_speed=[0]
  speed=[]
  whole_speed=[]
  for i in range(len(a)):
    for j in range(1,len(a[i])):
      tracewise_speed.append(((a[i][j]-a[i][j-1])**2-(b[i][j]-b[i][j-1])**2)**(0.5)/0.02)
    speed.append(tracewise_speed)
    tracewise_speed=[0]
  for i in range(len(speed)):
    for j in range(len(speed[i])):
      whole_speed.append(speed[i][j])
  features['speed']=whole_speed

  #Speed along x and y
  speed_x=[]
  speed_y=[]
  tracewise_speed_x=[]
  tracewise_speed_y=[]
  temp_x=[0]
  temp_y=[0]
  for i in range(len(a)):
    for j in range(1,len(a[i])):
      temp_x.append((a[i][j]-a[i][j-1])/0.02)
      temp_y.append((b[i][j]-b[i][j-1])/0.02)
    tracewise_speed_x.append(temp_x)
    tracewise_speed_y.append(temp_y)
    temp_x=[0]
    temp_y=[0]
  for i in range(len(tracewise_speed_x)):
    for j in range(len(tracewise_speed_x[i])):
      speed_x.append(tracewise_speed_x[i][j])
      speed_y.append(tracewise_speed_y[i][j])
  features['speed_x'] = speed_x
  features['speed_y'] = speed_y

  #Acceleration
  acc=[]
  tracewise_acc=[0]
  whole_acc=[]
  for i in range(len(speed)):
    for j in range(1,len(speed[i])):
      tracewise_acc.append((speed[i][j]-speed[i][j-1])/0.02)
    acc.append(tracewise_acc)
    tracewise_acc=[0]
  for i in range(len(acc)):
    for j in range(len(acc[i])):
      whole_acc.append(acc[i][j])
  features['acceleration']=whole_acc

  #Acceleration along x and y
  acc_x=[0]
  acc_y=[0]
  tracewise_acceleration_x=[]
  tracewise_acceleration_y=[]
  acceleration_x=[]
  acceleration_y=[]
  for i in range(len(tracewise_speed_x)):
    for j in range(1,len(tracewise_speed_x[i])):
      acc_x.append((tracewise_speed_x[i][j]-tracewise_speed_x[i][j-1])/0.02)
      acc_y.append((tracewise_speed_y[i][j]-tracewise_speed_y[i][j-1])/0.02)
    tracewise_acceleration_x.append(acc_x)
    tracewise_acceleration_y.append(acc_y)
    acc_x=[0]
    acc_y=[0]
  for i in range(len(tracewise_acceleration_x)):
    for j in range(len(tracewise_acceleration_x[i])):
      acceleration_x.append(tracewise_acceleration_x[i][j])
      acceleration_y.append(tracewise_acceleration_y[i][j])
  features['acceleration_x']=acceleration_x
  features['acceleration_y']=acceleration_y

  #Log curvature radius
  rad=[]
  tracewise_rad=[]
  whole_rad=[]
  for i in range(len(tracewise_speed_x)):
    for j in range(len(tracewise_speed_x[i])):
      nr=(tracewise_speed_x[i][j]*tracewise_acceleration_y[i][j]-tracewise_acceleration_x[i][j]-tracewise_speed_y[i][j])
      dr=(tracewise_speed_x[i][j]**2+tracewise_speed_y[i][j]**2)**(1.5)
      if (nr==0 or dr==0):
        tracewise_rad.append(0)
      else:
        tracewise_rad.append(nr/dr)
    rad.append(tracewise_rad)
    tracewise_rad=[]
  for i in range(len(rad)):
    for j in range(len(rad[i])):
      whole_rad.append(rad[i][j])
  features['log_curvature_radius']=whole_rad

  #writing direction
  tracewise_cos=[0]
  tracewise_sin=[0]
  cos=[]
  sin=[]
  whole_cos=[]
  whole_sin=[]
  for i in range(len(a)):
    for j in range(1,len(a[i])):
      l=((a[i][j]-a[i][j-1])**2+(b[i][j]-b[i][j-1])**2)**(0.5)
      tracewise_cos.append((a[i][j]-a[i][j-1])/l)
      tracewise_sin.append((b[i][j]-b[i][j-1])/l)
    cos.append(tracewise_cos)
    sin.append(tracewise_sin)
    tracewise_cos=[0]
    tracewise_sin=[0]
  for i in range(len(cos)):
    for j in range(len(cos[i])):
      whole_cos.append(cos[i][j])
      whole_sin.append(sin[i][j])
  features['writing_direction_x']=whole_cos
  features['writing_direction_y']=whole_sin

  #Curvature
  cur_x=[]
  cur_y=[]
  tracewise_cur_x=[0]
  tracewise_cur_y=[0]
  whole_cur_x=[]
  whole_cur_y=[]
  for i in range(len(cos)):
    for j in range(1,len(cos[i])):
      tracewise_cur_x.append(np.cos(cos[i][j-1])*np.cos(cos[i][j])+np.sin(cos[i][j-1])*np.sin(cos[i][j]))
      tracewise_cur_y.append(np.cos(sin[i][j-1])*np.sin(sin[i][j])-np.sin(sin[i][j-1])*np.cos(sin[i][j]))
    cur_x.append(tracewise_cur_x)
    cur_y.append(tracewise_cur_y)
    tracewise_cur_x=[0]
    tracewise_cur_y=[0]
  for i in range(len(cur_x)):
    for j in range(len(cur_x[i])):
      whole_cur_x.append(cur_x[i][j])
      whole_cur_y.append(cur_y[i][j])
  features['curvature_x']=whole_cur_x
  features['curvature_y']=whole_cur_y

  #Vicinity Aspect
  temp_x=[]
  temp_y=[]
  left_x=[]
  right_x=[]
  left_y=[]
  right_y=[]
  var=[]
  vc=[]
  vl=[]
  vs_cos=[]
  vs_sin=[]
  tracewise_var=[]
  for i in range(len(a)):
    for j in range(len(a[i])):
      if len(a[i])>=11:
        if len(a[i][:j])>5:
          left_x=a[i][j-5:j]
        elif len(a[i][:j])<=5:
          left_x=a[i][:j]
        if len(a[i][j+1:])>5:
          right_x=a[i][j+1:j+6]
        elif len(a[i][j+1:])<=5:
          right_x=a[i][j+1:]
      elif len(a[i])<11:
        if len(a[i][:j])>5:
          left_x=a[i][j-5:j]
        elif len(a[i][:j])<=5:
          left_x=a[i][:j]
        if len(a[i][j+1:])>5:
          right_x=a[i][j+1:j+6]
        elif len(a[i][j+1:])<=5:
          right_x=a[i][j+1:]

      if len(b[i])>=11:
        if len(b[i][:j])>5:
          left_y=b[i][j-5:j]
        elif len(b[i][:j])<=5:
          left_y=b[i][:j]
        if len(b[i][j+1:])>5:
          right_y=b[i][j+1:j+6]
        elif len(b[i][j+1:])<=5:
          right_y=b[i][j+1:]
      elif len(b[i])<11:
        if len(b[i][:j])>5:
          left_y=b[i][j-5:j]
        elif len(b[i][:j])<=5:
          left_y=b[i][:j]
        if len(b[i][j+1:])>5:
          right_y=b[i][j+1:j+6]
        elif len(b[i][j+1:])<=5:
          right_y=b[i][j+1:]

      left_x.append(a[i][j])
      left_y.append(b[i][j])
      temp_x=left_x+right_x
      temp_y=left_y+right_y
      dx=max(temp_x)-min(temp_x)
      dy=max(temp_y)-min(temp_y)
      if dx+dy==0:
        var.append(0)
      else:
        var.append((dy-dx)/(dx+dy))
      
      #vicinity_curliness
      dist=[]
      for k in range(1,len(temp_x)):
        dist.append(((temp_x[k]-temp_x[k-1])**2+(temp_y[k]-temp_y[k-1])**2)**(0.5))
      if dx+dy==0:
        vc.append(0)
      else:
        vc.append(sum(dist)/max(dx,dy))
      dist=[]

      #vicinity linearity
      if temp_x[-1]==temp_x[0]:
        slope = 'vertical_line'
      else:
        slope = (temp_y[-1]-temp_y[0])/(temp_x[-1]-temp_x[0])
      dist=[]
      for k in range(len(temp_x)):
        if slope=='vertical_line':
          dist.append(0)
        else:
          c=temp_y[0]-slope*temp_x[0]
          dist.append(((abs(slope*temp_x[k]-1*temp_y[k]+c))/(slope**2+1)**(0.5))**2)
      
      vl.append(mean(dist))
      dist=[]

      #vicinity slope
      if (temp_x[-1]-temp_x[0])==0:
        vs_cos.append(1)
        vs_sin.append(0)
      else:
        slope = (temp_y[-1]-temp_y[0])/(temp_x[-1]-temp_x[0])
        theta = math.atan(slope)
        vs_cos.append(math.sin(theta))
        vs_sin.append(math.cos(theta))

  features['vicinity_aspect']=var
  features['vicinity_curliness']=vc
  features['vicinity_linearity']=vl
  features['vicinity_slope_x']=vs_cos
  features['vicinity_slope_y']=vs_sin

  return(features)

# %%
def normalization(fea):
  fea_norm={}
  rex = fea['relative_x'];
  fea_norm["relative_x"] = stats.zscore(rex)
  rey = fea['relative_y'];
  fea_norm["relative_y"] = stats.zscore(rey)
  sp=fea['speed'];
  fea_norm["speed"] = stats.zscore(sp)
  sp_x = fea['speed_x'];
  fea_norm["speed_x"] = stats.zscore(sp_x)
  sp_y = fea['speed_y'];
  fea_norm["speed_y"] = stats.zscore(sp_y)
  acc = fea['acceleration'];
  fea_norm["acceleration"] = stats.zscore(acc)
  acc_x = fea['acceleration_x']
  fea_norm['acceleration_x'] = stats.zscore(acc_x)
  acc_y = fea['acceleration_y']
  fea_norm['acceleration_y'] = stats.zscore(acc_y)
  lcr = fea['log_curvature_radius'];
  fea_norm["log_curvature_radus"] = stats.zscore(lcr)
  wdx = fea['writing_direction_x'];
  fea_norm["writing_direction_x"] = stats.zscore(wdx)
  wdy = fea['writing_direction_y'];
  fea_norm["writing_direction_y"] = stats.zscore(wdy)
  cx = fea['curvature_x'];
  fea_norm["curvature_x"] = stats.zscore(cx)
  cy = fea['curvature_y'];
  fea_norm["curvature_y"] = stats.zscore(cy)
  va = fea['vicinity_aspect'];
  fea_norm["viscinity_aspect"] = stats.zscore(va)
  vc = fea['vicinity_curliness'];
  fea_norm["viscinity_curliness"] = stats.zscore(vc)
  vl = fea['vicinity_linearity'];
  fea_norm["viscinity_linearty"] = stats.zscore(vl)
  vsx = fea['vicinity_slope_x'];
  fea_norm["viscinity_slope_x"] = stats.zscore(vsx)
  vsy = fea['vicinity_slope_y'];
  fea_norm["viscinity_slope_y"] = stats.zscore(vsy)
  
  return fea_norm

# %%
folder_path='/content/drive/MyDrive/Datasets/Split_8_2/Test'

# %%
with open('/content/drive/MyDrive/Test.csv', 'w') as f:
  csvwriter = csv.writer(f)

  for writer in os.listdir(folder_path):
    csvwriter.writerow(writer)
    for sample in os.listdir(os.path.join(folder_path,writer)):
      sample_path = os.path.join(folder_path,writer,sample)
      print(sample_path)
      features = exctract_features(sample_path)
      normalized = normalization(features)
      a=[]
      for key, values in normalized.items():
        a.append(normalized[key])
      for x in a:
        csvwriter.writerow(x)
# Out:
# /content/drive/MyDrive/Datasets/Split_8_2/Test/40/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/40/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/40/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/40/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/40/17.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/40/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/9/24.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/56.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/50.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/62.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/64.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/44.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/52.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/7/67.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/44.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/29.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/35.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/41.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/6/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/36.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/24.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/63.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/69.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/66.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/5/60.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/44.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/53.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/50.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/56.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/43/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/8/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/8/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/8/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/25.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/42/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/60.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/62.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/45.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/41/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/62.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/65.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/74.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/47.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/41.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/29.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/68.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/35.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/71.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/4/53.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/73.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/50.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/44.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/65.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/62.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/35.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/70.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/57.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/56.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/38/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/84.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/78.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/85.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/63.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/69.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/66.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/60.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/31/80.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/5.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/39/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/68.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/81.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/47.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/53.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/50.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/59.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/17.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/78.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/34/74.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/19.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/70.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/64.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/7.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/82.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/76.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/96.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/25.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/52.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/10.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/33/88.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/25.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/63.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/17.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/45.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/5.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/23.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/36.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/30.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/32/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/24.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/41.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/35/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/37/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/37/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/29.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/50.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/23.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/53.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/30/41.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/80.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/76.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/67.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/64.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/55.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/61.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/36/40.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/25.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/29/19.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/53.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/44.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/7.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/57.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/5.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/50.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/47.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/24/19.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/21/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/21/10.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/21/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/21/7.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/36.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/72.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/74.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/45.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/65.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/63.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/57.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/69.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/27/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/60.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/75.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/36.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/72.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/28/66.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/52.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/19.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/23/40.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/30.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/36.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/52.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/55.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/25/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/5.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/61.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/55.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/74.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/70.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/10.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/19.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/3/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/70.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/66.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/57.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/63.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/30.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/26/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/22/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/22/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/5.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/12/40.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/7.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/55.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/29.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/43.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/17/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/60.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/33.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/73.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/66.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/74.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/72.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/21.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/18/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/13/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/13/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/79.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/73.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/47.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/40.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/64.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/67.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/88.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/30.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/16/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/4.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/63.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/75.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/15.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/60.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/7.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/72.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/49.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/52.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/12.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/54.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/15/18.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/10.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/40.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/19/5.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/48.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/17.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/39.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/14.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/67.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/29.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/55.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/35.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/2/6.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/46.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/56.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/10.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/52.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/7.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/30.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/40.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/20/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/22.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/19.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/44.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/9.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/51.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/14/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/2.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/38.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/26.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/37.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/58.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/61.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/45.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/67.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/42.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/53.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/29.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/1/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/13.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/16.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/27.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/23.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/32.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/11/3.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/20.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/17.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/45.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/56.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/68.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/31.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/36.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/41.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/8.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/1.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/34.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/28.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/11.inkml
# /content/drive/MyDrive/Datasets/Split_8_2/Test/10/59.inkml
